# %% [markdown]
# ### Generating Combined CSV Files

# %%
import os
import pandas as pd

def make_citizen_lab_list():
    # Directory containing the CSV files
    csv_directory = "../test-lists/lists/" # From cloned github: https://github.com/ooni/test-lists/tree/master
    # Ensure the directory exists
    if not os.path.exists(csv_directory):
        print(f"Directory {csv_directory} does not exist.")
        exit(1)

    # List all CSV files in the directory
    csv_files = [file for file in os.listdir(csv_directory) if file.endswith('.csv')]

    # Read and combine all CSV files into one DataFrame
    combined_df = pd.concat([pd.read_csv(os.path.join(csv_directory, file)) for file in csv_files])

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv("citizen_lab_censored.csv", index=False)

    print("Combined CSV saved as 'citizen_lab_censored.csv'")

    # Write only the 'url' column to a text file
    a = combined_df["url"]    
    a.to_csv("citizen_lab_censored.txt", index=False, header=False)
    return

# %%
import os
import pandas as pd

def combine_csvs(directory = "results/dpyproxy/frag_size=20__tcp_frag=True__record_frag=False/", name = ""): 
  
    # List to store DataFrames
    all_traffic_dataframes = []
    website_traffic_dataframes = []

    # Iterate through all files in the directory
    for root, _, files in os.walk(directory):
   
        for file in files:
            if file == "metrics_all.csv":
                file_path = os.path.join(root, file)
                try:
                    df = pd.read_csv(file_path)
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
                all_traffic_dataframes.append(df)
            elif file == "metrics_website_only.csv":
                try:
                    file_path = os.path.join(root, file)
                    df = pd.read_csv(file_path)
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
                    continue
                website_traffic_dataframes.append(df)

    # Combine all DataFrames into one
    all_traffic_combined_df = pd.concat(all_traffic_dataframes, ignore_index=True)
    website_traffic_combined_df = pd.concat(website_traffic_dataframes, ignore_index=True)    

    if name: 
        # Save the combined DataFrame to a new CSV file
        all_traffic_combined_df.to_csv(name + "_all_traffic.csv", index=False)
        website_traffic_combined_df.to_csv(name + "_website_only.csv", index=False)
    return all_traffic_combined_df, website_traffic_combined_df

baseline_all, baseline_website = combine_csvs(directory = "results/baseline", name = "combined_baseline")
dpyproxy_all, dpyproxy_website = combine_csvs(directory = "results/dpyproxy/frag_size=20__tcp_frag=True__record_frag=False/", name = "combined_dpyrpoxy")
# Out:
# Error reading results/dpyproxy/frag_size=20__tcp_frag=True__record_frag=False/bolod_mn__/metrics_website_only.csv: Error tokenizing data. C error: Expected 41 fields in line 5, saw 52

# %%
# Example 
dpyproxy_website["website"].value_counts()
# Out:
# website
# http://info.mn/                      10
# http://eagle.mn/                     10
# http://everyday.mn/                  10
# http://dorgio.mn/                    10
# http://www.smhric.org/               10
# http://www.ikon.mn/                  10
# http://zone.mn/                      10
# http://paparatsi.mn/                 10
# https://www.news.mn/                 10
# http://bataar.mn/                    10
# http://mnews.mn/                     10
# http://mongolnews.mn/                10
# http://wikimon.mn/                   10
# http://goolingoo.mn/                 10
# http://shuurhai.mn/                  10
# http://assa.mn/                      10
# http://sonin.mn/                     10
# http://16honeys.com/                 10
# http://sportnews.mn/                 10
# http://www.24tsag.mn/                10
# http://www.shuud.mn/                 10
# http://chuhal.mn/                    10
# http://mnb.mn/                       10
# http://vip76.mn/                     10
# http://ugluu.mn/                     10
# http://olloo.mn/                     10
# http://shudarga.mn/                  10
# http://orloo.info/                   10
# http://undesten.mn/                  10
# http://photonews.mn/                 10
# http://tsag.mn/                      10
# http://time.mn/                      10
# http://sharsonin.com/                10
# http://factnews.mn/                  10
# http://mass.mn/                      10
# http://mglclub.com/                  10
# http://gogo.mn/                      10
# http://medee.mn/                     10
# http://123moviesfreez.com/           10
# http://mminfo.mn/                    10
# http://mglradio.com/                 10
# http://dnn.mn/                       10
# http://unen.mn/                      10
# http://zindaa.mn/                    10
# http://www.caak.mn/                  10
# https://www.hrw.org/asia/mongolia     4
# Name: count, dtype: int64

# %% [markdown]
# ### Analysis

# %%
def calculate_col_means(df1, df2, df1_name = "DF1", df2_name = "DF2"): 

    # Calculate the mean of numerical columns for both dataframes
    df1_means= df1.mean(numeric_only=True)
    df2_means = df2.mean(numeric_only=True)

    # Combine the means into a single dataframe for comparison
    comparison = pd.DataFrame({df1_name: df1_means, df2_name: df2_means})
    comparison['Difference'] = comparison[df1_name] - comparison[df2_name]
    return comparison

# Filter for a specific website 
dpyproxy_website = pd.read_csv("combined_dpyproxy_website_only.csv")
baseline_website = pd.read_csv("combined_baseline_website_only.csv")

# Display the comparison (NOTE: this is for website traffic)
calculate_col_means(dpyproxy_website, baseline_website, df1_name = "Dpyproxy", df2_name = "Baseline")
# Out:
#                                     Dpyproxy       Baseline    Difference
# all_packet_average_size           500.273431     624.345146 -1.240717e+02
# all_packet_count                  155.762115     144.816810  1.094530e+01
# all_packet_max_size              1041.387665    1145.379310 -1.039916e+02
# all_packet_min_size                56.123348      59.495690 -3.372342e+00
# all_packet_total_size          118406.240088  128080.762931 -9.674523e+03
# data_avg_payload_size              36.799559      41.789665 -4.990106e+00
# data_count                         11.469163      10.109170  1.359993e+00
# data_max_payload_size              36.799559      43.362445 -6.562886e+00
# data_min_payload_size              36.799559      39.644105 -2.844545e+00
# data_total_payload_size            76.517621     129.635371 -5.311775e+01
# dns_count                           0.000000       0.000000  0.000000e+00
# dns_incomplete_transactions         0.000000       0.000000  0.000000e+00
# ip_count                          176.790000     152.715909  2.407409e+01
# ip_fragmentation_percentage         0.000000       0.000000  0.000000e+00
# ip_fragmented                       0.000000            NaN           NaN
# ip_packet_average_size            500.273431     624.345146 -1.240717e+02
# ip_packet_count                   155.762115            NaN           NaN
# ip_packet_max_size               1041.387665    1145.379310 -1.039916e+02
# ip_packet_min_size                 56.123348      59.495690 -3.372342e+00
# ip_packet_total_size           118406.240088  128080.762931 -9.674523e+03
# param_frag_size                    20.000000            NaN           NaN
# param_record_frag                   0.000000            NaN           NaN
# param_tcp_frag                      1.000000            NaN           NaN
# tcp_avg_rtt                         0.075887       0.045787  3.009990e-02
# tcp_count                         176.790000     152.715909  2.407409e+01
# tcp_duplicate_acks                  1.500000            NaN           NaN
# tcp_fast_retransmissions            0.195000       0.588636 -3.936364e-01
# tcp_max_rtt                         0.220690       0.213900  6.789983e-03
# tcp_min_rtt                         0.000066       0.000065  5.809091e-07
# tcp_packet_average_size           500.273431     624.345146 -1.240717e+02
# tcp_packet_count                  155.762115     144.816810  1.094530e+01
# tcp_packet_max_size              1041.387665    1145.379310 -1.039916e+02
# tcp_packet_min_size                56.123348      59.495690 -3.372342e+00
# tcp_packet_total_size          118406.240088  128080.762931 -9.674523e+03
# tcp_retransmission_percentage       3.610448       2.957036  6.534119e-01
# tcp_retransmissions                 1.832500       2.384091 -5.515909e-01
# udp_count                           0.000000            NaN           NaN
# udp_packet_average_size             0.000000            NaN           NaN
# udp_packet_count                    0.000000       0.000000  0.000000e+00
# udp_packet_max_size                 0.000000       0.000000  0.000000e+00
# udp_packet_min_size                 0.000000       0.000000  0.000000e+00
# udp_packet_total_size               0.000000       0.000000  0.000000e+00

# %%
### Avg RTT vs Data Size. 
### Frag Size 20 
### Header size? What is average? 
### Try Extreme: 2?

# %%
from scipy.stats import ttest_ind

# FIX: Compare distributions rather than means 

# Group by website and calculate the mean for each metric
baseline_grouped = baseline_website.groupby('website').mean(numeric_only=True)
dpyproxy_grouped = dpyproxy_website.groupby('website').mean(numeric_only=True)

# Combine the means into a single dataframe for comparison
comparison = pd.DataFrame({
    "Baseline": baseline_grouped.mean(numeric_only=True),
    "DPYProxy": dpyproxy_grouped.mean(numeric_only=True)
})
comparison['Difference'] = comparison["DPYProxy"] - comparison["Baseline"]

# Perform a T-test for each metric
p_values = {}
for column in baseline_grouped.columns:
    if column in dpyproxy_grouped.columns:
        t_stat, p_val = ttest_ind(baseline_grouped[column], dpyproxy_grouped[column], equal_var=False, nan_policy='omit')
        p_values[column] = p_val

# Add p-values to the comparison dataframe
comparison['P-Value'] = pd.Series(p_values)
# Add a column to indicate whether the P-Value is significant (e.g., p < 0.05)
comparison['Significant'] = comparison['P-Value'] < 0.05
# comparison['Difference'] = comparison["DPYProxy"] - comparison["Baseline"]

# Display the comparison dataframe
# Differentiate header vs payload 
# Check 
comparison
# Out:
#                                     Baseline       DPYProxy    Difference  \
# all_packet_average_size           616.374782     493.748126 -1.226267e+02
# all_packet_count                  142.968085     153.730435  1.076235e+01
# all_packet_max_size              1130.757447    1027.804348 -1.029531e+02
# all_packet_min_size                58.736170      55.391304 -3.344866e+00
# all_packet_total_size          126445.689362  116861.810870 -9.583878e+03
# data_avg_payload_size              40.722695      36.319565 -4.403130e+00
# data_count                          9.884397      11.319565  1.435168e+00
# data_max_payload_size              42.255319      36.319565 -5.935754e+00
# data_min_payload_size              38.631915      36.319565 -2.312350e+00
# data_total_payload_size           126.325532      75.519565 -5.080597e+01
# dns_count                           0.000000       0.000000  0.000000e+00
# dns_incomplete_transactions         0.000000       0.000000  0.000000e+00
# ip_count                          152.715909     176.790000  2.407409e+01
# ip_fragmentation_percentage         0.000000       0.000000  0.000000e+00
# ip_fragmented                            NaN       0.000000           NaN
# ip_packet_average_size            616.374782     493.748126 -1.226267e+02
# ip_packet_count                          NaN     153.730435           NaN
# ip_packet_max_size               1130.757447    1027.804348 -1.029531e+02
# ip_packet_min_size                 58.736170      55.391304 -3.344866e+00
# ip_packet_total_size           126445.689362  116861.810870 -9.583878e+03
# param_frag_size                          NaN      20.000000           NaN
# param_record_frag                        NaN       0.000000           NaN
# param_tcp_frag                           NaN       1.000000           NaN
# tcp_avg_rtt                         0.045787       0.075887  3.009990e-02
# tcp_count                         152.715909     176.790000  2.407409e+01
# tcp_duplicate_acks                       NaN       1.500000           NaN
# tcp_fast_retransmissions            0.588636       0.195000 -3.936364e-01
# tcp_max_rtt                         0.213900       0.220690  6.789983e-03
# tcp_min_rtt                         0.000065       0.000066  5.809091e-07
# tcp_packet_average_size           616.374782     493.748126 -1.226267e+02
# tcp_packet_count                  142.968085     153.730435  1.076235e+01
# tcp_packet_max_size              1130.757447    1027.804348 -1.029531e+02
# tcp_packet_min_size                58.736170      55.391304 -3.344866e+00
# tcp_packet_total_size          126445.689362  116861.810870 -9.583878e+03
# tcp_retransmission_percentage       2.957036       3.610448  6.534119e-01
# tcp_retransmissions                 2.384091       1.832500 -5.515909e-01
# udp_count                                NaN       0.000000           NaN
# udp_packet_average_size                  NaN       0.000000           NaN
# udp_packet_count                    0.000000       0.000000  0.000000e+00
# udp_packet_max_size                 0.000000       0.000000  0.000000e+00
# udp_packet_min_size                 0.000000       0.000000  0.000000e+00
# udp_packet_total_size               0.000000       0.000000  0.000000e+00
#
#                                 P-Value  Significant
# all_packet_average_size        0.087882        False
# all_packet_count               0.748926        False
# all_packet_max_size            0.307947        False
# all_packet_min_size            0.414330        False
# all_packet_total_size          0.775586        False
# data_avg_payload_size          0.831503        False
# data_count                     0.680246        False
# data_max_payload_size          0.776209        False
# data_min_payload_size          0.910080        False
# data_total_payload_size        0.509264        False
# dns_count                           NaN        False
# dns_incomplete_transactions         NaN        False
# ip_count                       0.499695        False
# ip_fragmentation_percentage         NaN        False
# ip_fragmented                       NaN        False
# ip_packet_average_size         0.087882        False
# ip_packet_count                     NaN        False
# ip_packet_max_size             0.307947        False
# ip_packet_min_size             0.414330        False
# ip_packet_total_size           0.775586        False
# param_frag_size                     NaN        False
# param_record_frag                   NaN        False
# param_tcp_frag                      NaN        False
# tcp_avg_rtt                    0.008690         True
# tcp_count                      0.499695        False
# tcp_duplicate_acks                  NaN        False
# tcp_fast_retransmissions       0.224686        False
# tcp_max_rtt                    0.835735        False
# tcp_min_rtt                    0.946912        False
# tcp_packet_average_size        0.087882        False
# tcp_packet_count               0.748926        False
# tcp_packet_max_size            0.307947        False
# tcp_packet_min_size            0.414330        False
# tcp_packet_total_size          0.775586        False
# tcp_retransmission_percentage  0.811573        False
# tcp_retransmissions            0.518456        False
# udp_count                           NaN        False
# udp_packet_average_size             NaN        False
# udp_packet_count                    NaN        False
# udp_packet_max_size                 NaN        False
# udp_packet_min_size                 NaN        False
# udp_packet_total_size               NaN        False
