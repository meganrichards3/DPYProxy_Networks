# %%
import os
import pandas as pd

def combine_csvs(directory = "results/baseline", name = "combined_baseline_results.csv"): 
  
    # List to store DataFrames
    dataframes = []

    # Iterate through all files in the directory
    for root, _, files in os.walk(directory):
        for file in files:
            if file == "metrics.csv":
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                dataframes.append(df)

    # Combine all DataFrames into one
    combined_df = pd.concat(dataframes, ignore_index=True)

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv(name, index=False)
    return combined_df

baseline = combine_csvs(directory = "results/baseline", name = "combined_baseline_results.csv")
dpyproxy = combine_csvs(directory = "results/dpyproxy", name = "combined_dpyrpoxy_results.csv")

# %%
baseline
# Out:
#          website                                    id                 date  \
# 0  wikipedia.org  85203ae5-45f5-4e53-b79c-c7ec811da151  2025-04-06 17:53:34
# 1  wikipedia.org  89b3463c-041c-4693-88b3-13620efb2c2f  2025-04-06 17:53:44
# 2  wikipedia.org  202aaad4-7570-4cee-85a1-092ce228813e  2025-04-06 18:02:34
# 3  wikipedia.org  95f4760e-27c4-4d8e-bfa7-c07bbaa7e87e  2025-04-06 18:02:42
#
#    packet_count                                       packet_sizes  \
# 0           246  [83, 73, 83, 125, 74, 73, 83, 73, 86, 78, 74, ...
# 1           244  [495, 75, 83, 73, 102, 118, 78, 150, 80, 74, 6...
# 2           404  [71, 68, 71, 68, 83, 73, 1392, 1242, 156, 1392...
# 3           310  [71, 68, 71, 68, 71, 68, 78, 74, 66, 1354, 615...
#
#    packet_total_size  packet_min_size  packet_max_size  packet_average_size  \
# 0             136718               54             1354           555.764228
# 1             129710               54             1354           531.598361
# 2             196199               54             1392           485.641089
# 3             138589               54             1354           447.061290
#
#    tcp_count  ...  tcp_fast_retransmissions  tcp_retransmission_percentage  \
# 0        189  ...                         0                       0.529101
# 1        197  ...                         0                       0.000000
# 2        288  ...                         0                       0.347222
# 3        203  ...                         0                       0.000000
#
#    tcp_min_rtt  tcp_max_rtt  tcp_avg_rtt  udp_count  rtp_count  dns_count  \
# 0     0.000049     0.079006     0.013706         57          0          0
# 1     0.000060     0.088948     0.012888         47          0          4
# 2     0.000034     0.088622     0.011468        116          0          2
# 3     0.000030     0.054247     0.006040        107          0          0
#
#    dns_incomplete_transactions  param_dpyproxy
# 0                            0           False
# 1                            0           False
# 2                            0           False
# 3                            0           False
#
# [4 rows x 22 columns]

# %%
dpyproxy
# Out:
#          website                                    id                 date  \
# 0  wikipedia.org  e928cfb9-4df9-42f4-b48f-5237b7e6e2c3  2025-04-06 18:00:17
# 1  wikipedia.org  c33f3eff-9b76-4cde-9aea-80ba27afa817  2025-04-06 18:00:29
# 2  wikipedia.org  aa9929a3-0c6b-4c88-a6d5-8c3455280225  2025-04-06 18:02:15
# 3  wikipedia.org  394df305-91c9-4a2e-a12f-2d4e1879ea24  2025-04-06 18:02:26
#
#    packet_count                                       packet_sizes  \
# 0          1159  [85, 71, 67, 530, 66, 90, 66, 66, 83, 73, 71, ...
# 1           318  [71, 67, 120, 115, 108, 78, 87, 66, 122, 66, 8...
# 2           564  [71, 67, 71, 68, 83, 73, 83, 125, 74, 74, 73, ...
# 3           388  [122, 75, 346, 66, 71, 68, 122, 75, 83, 73, 71...
#
#    packet_total_size  packet_min_size  packet_max_size  packet_average_size  \
# 0             551599               54             1392           475.926661
# 1             126646               54             1354           398.257862
# 2             291478               42             1354           516.804965
# 3             154970               54             1354           399.407216
#
#    tcp_count  ...  tcp_min_rtt  tcp_max_rtt  tcp_avg_rtt  udp_count  \
# 0        584  ...     0.000030     0.085147     0.005859        572
# 1        212  ...     0.000037     0.023381     0.004542        105
# 2        418  ...     0.000042     0.262046     0.009616        144
# 3        300  ...     0.000044     0.060353     0.006116         88
#
#    rtp_count  dns_count  dns_incomplete_transactions  param_frag_size  \
# 0          0         36                            0               20
# 1          0          0                            0               20
# 2          0         12                            0               20
# 3          0          2                            0               20
#
#    param_tcp_frag  param_record_frag
# 0            True               True
# 1            True               True
# 2            True               True
# 3            True               True
#
# [4 rows x 24 columns]
