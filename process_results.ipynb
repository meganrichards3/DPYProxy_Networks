# %%
import os
import pandas as pd

def make_citizen_lab_list():
    # Directory containing the CSV files
    csv_directory = "../test-lists/lists/" # From cloned github: https://github.com/ooni/test-lists/tree/master
    # Ensure the directory exists
    if not os.path.exists(csv_directory):
        print(f"Directory {csv_directory} does not exist.")
        exit(1)

    # List all CSV files in the directory
    csv_files = [file for file in os.listdir(csv_directory) if file.endswith('.csv')]

    # Read and combine all CSV files into one DataFrame
    combined_df = pd.concat([pd.read_csv(os.path.join(csv_directory, file)) for file in csv_files])

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv("citizen_lab_censored.csv", index=False)

    print("Combined CSV saved as 'citizen_lab_censored.csv'")

# %%
import os
import pandas as pd

def combine_csvs(directory = "results/baseline", name = "combined_baseline_results.csv"): 
  
    # List to store DataFrames
    dataframes = []

    # Iterate through all files in the directory
    for root, _, files in os.walk(directory):
        for file in files:
            if file == "metrics.csv":
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                dataframes.append(df)

    # Combine all DataFrames into one
    combined_df = pd.concat(dataframes, ignore_index=True)

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv(name, index=False)
    return combined_df

baseline = combine_csvs(directory = "results/baseline", name = "combined_baseline_results.csv")
dpyproxy = combine_csvs(directory = "results/dpyproxy", name = "combined_dpyrpoxy_results.csv")

# %%
baseline[baseline['website'] == 'wikipedia.org']
# Out:
#          website                                    id                 date  \
# 0  wikipedia.org  0302c7e0-0941-4c42-ab50-4ef489ff7ff1  2025-04-06 18:13:32
# 1  wikipedia.org  3d7ca456-b0ef-4606-a60a-db1ea3663dd8  2025-04-06 18:13:40
# 2  wikipedia.org  dde6e543-5096-427a-b8bf-efab183ef5fe  2025-04-06 18:13:48
# 3  wikipedia.org  7eeeeb4b-117a-40cb-93f0-29ad7b8fa546  2025-04-06 18:13:56
# 4  wikipedia.org  4b3dd246-dbcb-4bbb-b3a5-367f80dd9ef8  2025-04-06 18:14:05
# 5  wikipedia.org  ea688d06-c611-490e-b11f-adc58ec99833  2025-04-06 18:14:13
# 6  wikipedia.org  f1e520e8-00d8-4eca-9944-e49e11c4b64f  2025-04-06 18:14:21
# 7  wikipedia.org  a379d451-e5c3-4514-bb98-904829cd6b87  2025-04-06 18:14:30
# 8  wikipedia.org  87de9e0c-08fe-483e-87f3-d1d0ea93eeb3  2025-04-06 18:14:39
# 9  wikipedia.org  2aaf6fdb-d9c2-465c-8a51-0bf06704fbf9  2025-04-06 18:14:47
#
#    packet_count                                       packet_sizes  \
# 0           234  [495, 75, 123, 66, 75, 283, 120, 63, 77, 369, ...
# 1           177  [123, 78, 122, 78, 54, 66, 71, 67, 78, 74, 66,...
# 2           216  [122, 79, 120, 122, 66, 90, 66, 94, 66, 77, 75...
# 3           342  [71, 67, 1292, 1292, 124, 607, 82, 1292, 1292,...
# 4           242  [83, 73, 87, 107, 158, 66, 167, 78, 74, 66, 38...
# 5           254  [495, 75, 75, 75, 125, 91, 1292, 1292, 121, 42...
# 6           575  [71, 69, 123, 75, 123, 75, 93, 149, 78, 74, 66...
# 7           547  [71, 67, 83, 73, 54, 71, 67, 78, 74, 66, 389, ...
# 8           246  [120, 122, 75, 66, 122, 66, 495, 75, 78, 74, 6...
# 9           224  [71, 67, 123, 75, 42, 78, 42, 78, 66, 66, 107,...
#
#    packet_total_size  packet_min_size  packet_max_size  packet_average_size  \
# 0             133479               54             1354           570.423077
# 1             114848               54             1354           648.858757
# 2             117239               54             1354           542.773148
# 3             195348               54             1354           571.192982
# 4             132969               54             1354           549.458678
# 5             132462               54             1354           521.503937
# 6             400504               54             1354           696.528696
# 7             437500               54             1392           799.817185
# 8             130225               54             1354           529.369919
# 9             131819               42             1354           588.477679
#
#    tcp_count  ...  tcp_fast_retransmissions  tcp_retransmission_percentage  \
# 0        193  ...                         0                       0.000000
# 1        167  ...                         0                       0.000000
# 2        172  ...                         0                       0.000000
# 3        201  ...                         0                       0.497512
# 4        199  ...                         0                       0.000000
# 5        179  ...                         0                       0.000000
# 6        512  ...                         0                       0.390625
# 7        476  ...                         0                       0.840336
# 8        181  ...                         0                       0.000000
# 9        208  ...                         0                       0.000000
#
#    tcp_min_rtt  tcp_max_rtt  tcp_avg_rtt  udp_count  rtp_count  dns_count  \
# 0     0.000046     0.063415     0.010968         41          0          4
# 1     0.000031     0.048170     0.004816         10          0          0
# 2     0.000053     0.056091     0.004658         44          0          0
# 3     0.000049     0.055825     0.004887        141          0          4
# 4     0.000036     0.052327     0.005111         42          0         10
# 5     0.000046     0.056082     0.005958         75          0          6
# 6     0.000059     0.078717     0.006328         63          0         10
# 7     0.000023     0.053463     0.003053         71          0          4
# 8     0.000034     0.053338     0.004951         65          0          4
# 9     0.000045     0.064458     0.005845         14          0          2
#
#    dns_incomplete_transactions  param_dpyproxy
# 0                            0           False
# 1                            0           False
# 2                            0           False
# 3                            0           False
# 4                            0           False
# 5                            0           False
# 6                            0           False
# 7                            0           False
# 8                            0           False
# 9                            0           False
#
# [10 rows x 22 columns]

# %%
dpyproxy[dpyproxy['website'] == 'wikipedia.org']
# Out:
#          website                                    id                 date  \
# 0  wikipedia.org  bcc57941-ecf6-40fc-bc9e-39f6a0230b8f  2025-04-06 18:11:51
# 1  wikipedia.org  ecf4e7a7-f394-4cbe-a62e-3a736cb6dbc1  2025-04-06 18:12:02
# 2  wikipedia.org  004f8d91-3fd8-40ab-9686-578ac82b9021  2025-04-06 18:12:12
# 3  wikipedia.org  67f90b51-b8c1-4bc6-8b1c-5508d6a57061  2025-04-06 18:12:23
# 4  wikipedia.org  d8dc3eef-1e79-4a12-81e8-991ddf96f1fe  2025-04-06 18:12:33
# 5  wikipedia.org  51d0a1bd-2967-4a68-bdbd-b0ace7f01fbd  2025-04-06 18:12:43
# 6  wikipedia.org  81a0b552-94c1-44fc-94af-e718a144effb  2025-04-06 18:12:53
# 7  wikipedia.org  f4c2ecdc-a64a-4e5a-b332-f7118ab7b4b5  2025-04-06 18:13:04
# 8  wikipedia.org  39e10e83-5a6f-467d-9094-d20b1ed8eca4  2025-04-06 18:13:14
# 9  wikipedia.org  51ee2c0e-8cab-4c77-b868-2d9029031276  2025-04-06 18:13:24
#
#    packet_count                                       packet_sizes  \
# 0           289  [123, 78, 54, 66, 73, 89, 78, 74, 66, 91, 91, ...
# 1           550  [77, 77, 76, 71, 67, 66, 71, 78, 1292, 1292, 1...
# 2           243  [123, 79, 66, 66, 66, 160, 66, 1037, 71, 713, ...
# 3           379  [90, 66, 66, 66, 66, 76, 76, 66, 111, 169, 78,...
# 4           318  [94, 94, 389, 366, 136, 223, 78, 74, 66, 366, ...
# 5           243  [97, 66, 66, 66, 83, 83, 73, 73, 78, 74, 66, 9...
# 6           233  [71, 67, 71, 67, 123, 75, 78, 74, 66, 91, 91, ...
# 7           303  [71, 67, 83, 83, 201, 143, 1292, 1292, 82, 66,...
# 8           313  [552, 126, 92, 73, 78, 74, 66, 583, 66, 464, 6...
# 9           327  [66, 78, 1134, 66, 91, 66, 95, 66, 71, 67, 83,...
#
#    packet_total_size  packet_min_size  packet_max_size  packet_average_size  \
# 0             142363               54             1354           492.605536
# 1             241114               54             1392           438.389091
# 2             121377               54             1354           499.493827
# 3             183666               42             1354           484.606860
# 4             135257               54             1354           425.336478
# 5             122858               54             1354           505.588477
# 6             118915               54             1354           510.364807
# 7             137220               54             1354           452.871287
# 8             147660               54             1354           471.757188
# 9             141243               54             1354           431.935780
#
#    tcp_count  ...  tcp_min_rtt  tcp_max_rtt  tcp_avg_rtt  udp_count  \
# 0        252  ...     0.000042     0.016505     0.004530         37
# 1        325  ...     0.000023     0.215581     0.013408        225
# 2        221  ...     0.000018     0.023981     0.004609         22
# 3        355  ...     0.000019     0.053141     0.005554         22
# 4        259  ...     0.000017     0.440302     0.013573         58
# 5        229  ...     0.000017     0.024032     0.004882         14
# 6        213  ...     0.000045     0.082885     0.006314         20
# 7        232  ...     0.000057     0.082266     0.005983         71
# 8        220  ...     0.000042     0.081914     0.006508         93
# 9        268  ...     0.000025     0.130463     0.013247         59
#
#    rtp_count  dns_count  dns_incomplete_transactions  param_frag_size  \
# 0          0          4                            0               20
# 1          0          2                            0               20
# 2          0          0                            0               20
# 3          0          8                            0               20
# 4          0          6                            0               20
# 5          0          0                            0               20
# 6          0          0                            0               20
# 7          0          4                            0               20
# 8          0          4                            0               20
# 9          0          6                            0               20
#
#    param_tcp_frag  param_record_frag
# 0           False              False
# 1           False              False
# 2           False              False
# 3           False              False
# 4           False              False
# 5           False              False
# 6           False              False
# 7           False              False
# 8           False              False
# 9           False              False
#
# [10 rows x 24 columns]

# %%
# Calculate the mean of numerical columns for both dataframes
baseline_means = baseline.mean(numeric_only=True)
dpyproxy_means = dpyproxy.mean(numeric_only=True)

# Combine the means into a single dataframe for comparison
comparison = pd.DataFrame({'Baseline': baseline_means, 'Dpyproxy': dpyproxy_means})
comparison['Difference'] = comparison['Dpyproxy'] - comparison['Baseline']

# Display the comparison
comparison
# Out:
#                                     Baseline       Dpyproxy    Difference
# dns_count                           4.400000       3.400000     -1.000000
# dns_incomplete_transactions         0.000000       0.000000      0.000000
# packet_average_size               601.840406     471.294933   -130.545472
# packet_count                      305.700000     319.800000     14.100000
# packet_max_size                  1357.800000    1357.800000      0.000000
# packet_min_size                    52.800000      52.800000      0.000000
# packet_total_size              192639.300000  149167.300000 -43472.000000
# param_dpyproxy                      0.000000            NaN           NaN
# param_frag_size                          NaN      20.000000           NaN
# param_record_frag                        NaN       0.000000           NaN
# param_tcp_frag                           NaN       0.000000           NaN
# rtp_count                           0.000000       0.000000      0.000000
# tcp_avg_rtt                         0.005658       0.007861      0.002204
# tcp_count                         248.800000     257.400000      8.600000
# tcp_duplicate_acks                  1.800000       1.100000     -0.700000
# tcp_fast_retransmissions            0.000000       0.000000      0.000000
# tcp_max_rtt                         0.058189       0.115107      0.056918
# tcp_min_rtt                         0.000042       0.000030     -0.000012
# tcp_retransmission_percentage       0.172847       0.473592      0.300745
# tcp_retransmissions                 0.700000       1.400000      0.700000
# udp_count                          56.600000      62.100000      5.500000
